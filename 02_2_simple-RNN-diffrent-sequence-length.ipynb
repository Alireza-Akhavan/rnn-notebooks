# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
# <img src="./logo.png" alt="class.vision" style="width: 200px;"/>
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">تغییر در طول بازه‌های زمانی ورودی شبکه - روش 2</div></center></h1>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import os
# %matplotlib inline

t = np.arange(0,1500)
x = np.sin(0.02*t)+ np.random.rand(1500) * 2

train,test = x[0:1000], x[1000:]

# convert into dataset data and label
def convertToDataset(data, step):
    #data = np.append(data,np.repeat(data[-1,],step))
    X, Y =[], []
    for i in range(len(data)-step):
        d=i+step  
        X.append(data[i:d,])
        Y.append(data[d,])
    return np.array(X), np.array(Y)

# %%
train_step = 10
test_step = 20

trainX,trainY =convertToDataset(train,train_step)
testX,testY =convertToDataset(test,test_step)

trainX = np.reshape(trainX, (trainX.shape[0],  trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0],testX.shape[1], 1))

# %%
print(trainX.shape)
print(testX.shape)
# Out:
# (990, 10, 1)
# (480, 20, 1)

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">معماری شبکه و compile آن</div>

# %%
def build_model(sequence_length):
    model = Sequential()
    model.add(SimpleRNN(units=64, input_shape=(sequence_length, 1),  activation="tanh"))
    model.add(Dense(1))
    return model

# %%
model = build_model(10)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 64)                4224
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 4,289
# Trainable params: 4,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.input
# Out:
# <tf.Tensor 'simple_rnn_input:0' shape=(?, 10, 1) dtype=float32>

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">آموزش مدل</div>

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = './notebook02_training_checkpoints'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback=ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True)

# %%
history = model.fit(trainX,trainY, epochs=100, batch_size=16,
                    verbose=2, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 3s - loss: 0.4920
# Epoch 2/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.4102
# Epoch 3/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.4077
# Epoch 4/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3988
# Epoch 5/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3925
# Epoch 6/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.4015
# Epoch 7/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.4000
# Epoch 8/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3984
# Epoch 9/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3925
# Epoch 10/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3851
# Epoch 11/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3976
# Epoch 12/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3905
# Epoch 13/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3893
# Epoch 14/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3872
# Epoch 15/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3872
# Epoch 16/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3846
# Epoch 17/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3850
# Epoch 18/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3761
# Epoch 19/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3787
# Epoch 20/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3866
# Epoch 21/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3835
# Epoch 22/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3744
# Epoch 23/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3782
# Epoch 24/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3821
# Epoch 25/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3776
# Epoch 26/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3718
# Epoch 27/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3717
# Epoch 28/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3737
# Epoch 29/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3653
# Epoch 30/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3704
# Epoch 31/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3659
# Epoch 32/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3701
# Epoch 33/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3663
# Epoch 34/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3637
# Epoch 35/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3555
# Epoch 36/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3543
# Epoch 37/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3566
# Epoch 38/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3466
# Epoch 39/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3438
# Epoch 40/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3463
# Epoch 41/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3561
# Epoch 42/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3459
# Epoch 43/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3381
# Epoch 44/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3365
# Epoch 45/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3412
# Epoch 46/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3426
# Epoch 47/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3295
# Epoch 48/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3220
# Epoch 49/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3177
# Epoch 50/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3178
# Epoch 51/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3078
# Epoch 52/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3301
# Epoch 53/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3137
# Epoch 54/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.3016
# Epoch 55/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2949
# Epoch 56/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2980
# Epoch 57/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2944
# Epoch 58/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2972
# Epoch 59/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2902
# Epoch 60/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2859
# Epoch 61/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2773
# Epoch 62/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2800
# Epoch 63/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2620
# Epoch 64/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2646
# Epoch 65/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2577
# Epoch 66/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2543
# Epoch 67/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2483
# Epoch 68/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2405
# Epoch 69/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2337
# Epoch 70/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2342
# Epoch 71/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2173
# Epoch 72/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2247
# Epoch 73/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2170
# Epoch 74/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2205
# Epoch 75/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2102
# Epoch 76/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2108
# Epoch 77/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1987
# Epoch 78/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1991
# Epoch 79/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.2037
# Epoch 80/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1884
# Epoch 81/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1865
# Epoch 82/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1899
# Epoch 83/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1786
# Epoch 84/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1767
# Epoch 85/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1744
# Epoch 86/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1722
# Epoch 87/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1584
# Epoch 88/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1574
# Epoch 89/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1525
# Epoch 90/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1518
# Epoch 91/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1574
# Epoch 92/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1444
# Epoch 93/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1486
# Epoch 94/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1365
# Epoch 95/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1379
# Epoch 96/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1279
# Epoch 97/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1311
# Epoch 98/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1216
# Epoch 99/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1223
# Epoch 100/100
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x000002AD84DA83C8>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
#  - 1s - loss: 0.1285

# %% [markdown]
# # <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> ارزیابی مدل</div>

# %%
tf.train.latest_checkpoint(checkpoint_dir)
# Out:
# './notebook02_training_checkpoints\\ckpt_100'

# %%
model = build_model(20)

model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
trainScore = model.evaluate(testX, testY, verbose=0)
print(trainScore)
# Out:
# 0.841938066482544

# %% [markdown]
# <div class="alert alert-block alert-info">
# <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma"> دوره پیشرفته یادگیری عمیق<br>علیرضا اخوان پور<br>  آبان و آذر 1399<br>
# </div>
# <a href="http://class.vision">Class.Vision</a> - <a href="http://AkhavanPour.ir">AkhavanPour.ir</a> - <a href="https://github.com/Alireza-Akhavan/">GitHub</a>
#
# </div>
